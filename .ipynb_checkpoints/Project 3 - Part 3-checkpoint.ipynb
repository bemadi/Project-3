# %% [markdown]
# Part 3 - ETL
#
# Create a MySQL database for the data we've cleaned and collected.
#
# Normalize the tables before adding them to the database.
#     - Convert a single string of genres from title basics into 2 tables
#
#     1. title_genres: with the columns:
#         - tconst
#         - genre_id
#     2. genres:
#         - genre_id
#         - genre_name
#
# Discard unnecessary columns: original_title, isAdult, titleType, genres. DO NOT include titles_akas table in your database
#
# MySQL Database Requirements
# - Use sqlalchemy with pandas to execute SQL quries inside your notebook
# - Create a new database on your MySQL server and call it 'movies' with the following tables

# %%
import pandas as pd
import numpy as np

# %%
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                   Grizzly II: The Predator        0       2020      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4              74   Horror,Music,Thriller

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79287 entries, 0 to 79286
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          79287 non-null  object
#  1   titleType       79287 non-null  object
#  2   primaryTitle    79287 non-null  object
#  3   originalTitle   79287 non-null  object
#  4   isAdult         79287 non-null  int64
#  5   startYear       79287 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  79287 non-null  int64
#  8   genres          79287 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.4+ MB

# %% [markdown]
# **Step 1: Normalization**

# %%
# Create a column with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                   Grizzly II: The Predator        0       2020      NaN
#
#    runtimeMinutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2             122                   Drama                     [Drama]
# 3             100    Comedy,Horror,Sci-Fi    [Comedy, Horror, Sci-Fi]
# 4              74   Horror,Music,Thriller   [Horror, Music, Thriller]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 79285  tt9916190     movie                                          Safeguard
# 79285  tt9916190     movie                                          Safeguard
# 79285  tt9916190     movie                                          Safeguard
# 79286  tt9916362     movie                                              Coven
# 79286  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 79285                                  Safeguard        0       2020      NaN
# 79285                                  Safeguard        0       2020      NaN
# 79285                                  Safeguard        0       2020      NaN
# 79286                                   Akelarre        0       2020      NaN
# 79286                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 79285              90  Action,Adventure,Thriller       Action
# 79285              90  Action,Adventure,Thriller    Adventure
# 79285              90  Action,Adventure,Thriller     Thriller
# 79286              92              Drama,History        Drama
# 79286              92              Drama,History      History
#
# [148239 rows x 10 columns]

# %%
genres_split = basics['genres'].str.split(",")

# %%
unique_genres = genres_split.explode().unique()
unique_genres
# Out:
# array(['Comedy', 'Fantasy', 'Romance', 'Drama', 'Horror', 'Sci-Fi',
#        'Music', 'Thriller', 'Mystery', 'Musical', 'Action', 'Adventure',
#        'Crime', 'Animation', 'Family', 'History', 'War', 'Biography',
#        'Sport', 'Western', 'Adult', 'Short', 'Reality-TV', 'News',
#        'Talk-Show', 'Game-Show'], dtype=object)

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %% [markdown]
# **2. Create a new title_genres table**

# %%
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %% [markdown]
# **3. Create a genre mapper dictionary to replace string genres with integers**

# %%
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %% [markdown]
# **4. Replace the string genres in title_genres with the new integer ids**

# %%
title_genres['genre_id'] = title_genres['genres_split'].map(genre_id_map)
title_genres = title_genres.drop(columns='genres_split')
title_genres
# Out:
#           tconst  genre_id
# 0      tt0035423         5
# 0      tt0035423         9
# 0      tt0035423        18
# 1      tt0062336         7
# 2      tt0069049         7
# ...          ...       ...
# 79285  tt9916190         0
# 79285  tt9916190         2
# 79285  tt9916190        23
# 79286  tt9916362         7
# 79286  tt9916362        11
#
# [148239 rows x 2 columns]

# %% [markdown]
# **5. Convert the genre map dictionary into a dataframe**

# %%
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                            'Genre_ID': genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# **Saving the MySQL tables with tconst as the Primary Key**
#
# **Basics Table**
#
# **1. Creating a datatype schema for to_sql**

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0093119     movie                                Grizzly II: Revenge
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                   Grizzly II: The Predator        0       2020      NaN
#
#    runtimeMinutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2             122                   Drama                     [Drama]
# 3             100    Comedy,Horror,Sci-Fi    [Comedy, Horror, Sci-Fi]
# 4              74   Horror,Music,Thriller   [Horror, Music, Thriller]

# %%
basics = basics.drop(columns=['originalTitle', 'isAdult', 'titleType', 'genres', 'genres_split'])

# %%
basics.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold       2001
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...       2020
# 2  tt0069049                         The Other Side of the Wind       2018
# 3  tt0088751                                  The Naked Monster       2005
# 4  tt0093119                                Grizzly II: Revenge       2020
#
#    endYear  runtimeMinutes
# 0      NaN             118
# 1      NaN              70
# 2      NaN             122
# 3      NaN             100
# 4      NaN              74

# %%
max_str_length = basics['tconst'].fillna('').map(len).max()

# %%
max_str_length
# Out:
# 10

# %%
from sqlalchemy.types import *
key_len = max_str_length
title_len = basics['primaryTitle'].fillna('').map(len).max()
basics_schema = {
    "tconst": String(key_len+1),
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()
}

# %% [markdown]
# **2. Run df.to_sql with the dtype argument**

# %%
from sqlalchemy_utils import create_database, database_exists

# %%
# create_database(connection)

# %%
from sqlalchemy import create_engine

# %%
connection = "mysql+pymysql://root:root@localhost/movies"
engine = create_engine(connection)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=basics_schema,if_exists='replace',index=False)

# %% [markdown]
# **3. Run the query to add the primary key**

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %% [markdown]
# **Ratings Table**

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz')
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1882
# 1  tt0000002            5.9       250
# 2  tt0000003            6.5      1663
# 3  tt0000004            5.8       163
# 4  tt0000005            6.2      2487

# %%
max_str_len = ratings['tconst'].fillna('').map(len).max()
max_str_len
# Out:
# 10

# %%
key_len = ratings['tconst'].fillna('').map(len).max()
ratings_schema = {
    "tconst": String(key_len+1),
    "averageRating": Float(),
    "numVotes": Integer()
}

# %%
ratings.to_sql('title_ratings',engine,dtype=ratings_schema,if_exists='replace',index=False)

# %% [markdown]
# **Genres**

# %%
max_str_len = title_genres['tconst'].fillna('').map(len).max()
max_str_len
# Out:
# 10

# %%
key_len = title_genres['tconst'].fillna('').map(len).max()
title_genres_schema = {
    "tconst": String(key_len+1),
    "genre_id": Integer() 
}

# %%
title_genres.to_sql('title_genres',engine,dtype=title_genres_schema,if_exists='replace',index=False)

# %%
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
max_str_length = genre_lookup['Genre_Name'].fillna('').map(len).max()

# %%
genre_lookup_schema = {
    "Genre_Name": String(max_str_len+1),
    "Genre_ID": Integer()
}

# %%
genre_lookup.to_sql('genres',engine,dtype=genre_lookup_schema,if_exists='replace',index=False)

# %% [markdown]
# **TMDB Data**

# %%
import glob
import os

# %%
tmdb_2000 = pd.read_csv(r'Data/final_tmdb_data_2000.csv.gz')
tmdb_2000
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1193  tt6174238    0.0                               NaN
# 1194  tt7029820    0.0                               NaN
# 1195  tt7197642    0.0                               NaN
# 1196  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1197  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN  10000000.0
# 2                                                   NaN         0.0
# 3                                                   NaN         0.0
# 4                                                   NaN    150000.0
# ...                                                 ...         ...
# 1193  {'id': 404302, 'name': 'Cold War Collection', ...         0.0
# 1194                                                NaN         0.0
# 1195                                                NaN         0.0
# 1196                                                NaN  10000000.0
# 1197                                                NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1193                      [{'id': 80, 'name': 'Crime'}]
# 1194                                                 []
# 1195                     [{'id': 35, 'name': 'Comedy'}]
# 1196                     [{'id': 27, 'name': 'Horror'}]
# 1197  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                   homepage        id original_language  \
# 0                                      NaN       NaN               NaN
# 1                                      NaN   62127.0                en
# 2                                      NaN  110977.0                en
# 3                                      NaN  442869.0                hi
# 4     http://www.wkw-inthemoodforlove.com/     843.0                cn
# ...                                    ...       ...               ...
# 1193                                   NaN  223878.0                en
# 1194                                   NaN  604889.0                en
# 1195                                   NaN  872676.0                en
# 1196                                   NaN   97186.0                fr
# 1197                                   NaN  610992.0                fa
#
#                original_title  ...     revenue  runtime  \
# 0                         NaN  ...         NaN      NaN
# 1             The Fantasticks  ...         0.0     86.0
# 2               For the Cause  ...         0.0    100.0
# 3                        Gang  ...         0.0    152.0
# 4                        花樣年華  ...  12854953.0     99.0
# ...                       ...  ...         ...      ...
# 1193                 Cold War  ...         0.0      0.0
# 1194     Scream For Christmas  ...         0.0     80.0
# 1195  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 1196               I, Vampire  ...         0.0     85.0
# 1197                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1193  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1194                                                 []  Released
# 1195                                                 []  Released
# 1196  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1197  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1193                                                NaN
# 1194                                                NaN
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0           5.4       21.0           NaN
# 2               For the Cause    0.0           4.4        7.0           NaN
# 3                        Gang    0.0           0.0        0.0           NaN
# 4        In the Mood for Love    0.0           8.1     1882.0            PG
# ...                       ...    ...           ...        ...           ...
# 1193                 Cold War    0.0           2.0        2.0           NaN
# 1194     Scream For Christmas    0.0           0.0        0.0           NaN
# 1195  Goodbye, Merry-Go-Round    0.0           0.0        0.0           NaN
# 1196               I, Vampire    0.0           6.4        4.0            NR
# 1197              The Mummy 3    0.0           7.0        1.0           NaN
#
# [1198 rows x 26 columns]

# %%
tmdb_2001 = pd.read_csv(r'Data/final_tmdb_data_2001.csv.gz')
tmdb_2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0118589    0.0  /bLntSfsqUheiUirdV9Ts8znqsTM.jpg
# 4     tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
# ...         ...    ...                               ...
# 1276  tt7797670    0.0                               NaN
# 1277  tt7797790    0.0                               NaN
# 1278  tt8665056    0.0                               NaN
# 1279  tt8795764    0.0                               NaN
# 1280  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN  22000000.0
# 4                      NaN   1000000.0
# ...                    ...         ...
# 1276                   NaN         0.0
# 1277                   NaN         0.0
# 1278                   NaN         0.0
# 1279                   NaN         0.0
# 1280                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 4     [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...
# ...                                                 ...
# 1276                     [{'id': 27, 'name': 'Horror'}]
# 1277                     [{'id': 27, 'name': 'Horror'}]
# 1278                    [{'id': 37, 'name': 'Western'}]
# 1279                     [{'id': 27, 'name': 'Horror'}]
# 1280                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   11232.0
# 2                                                   NaN  151007.0
# 3                                                   NaN   10696.0
# 4                                                   NaN   17140.0
# ...                                                 ...       ...
# 1276                                                NaN  956214.0
# 1277                                                NaN  956219.0
# 1278  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1279  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1280    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                              Kate & Leopold  ...
# 2                   en                            The Silent Force  ...
# 3                   en                                     Glitter  ...
# 4                   en                       The Attic Expeditions  ...
# ...                ...                                         ...  ...
# 1276                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 1277                en         Edmund Kemper Part 3: La mort sévit  ...
# 1278                en                        Guns Along The Bravo  ...
# 1279                en                                   New Breed  ...
# 1280                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1     76019048.0    118.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      5271666.0    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 1276         0.0     91.0                                                 []
# 1277         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1278         0.0     85.0                                                 []
# 1279         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1280         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released  If they lived in the same century they'd be pe...
# 2     Released  They left him for dead... They should have fin...
# 3     Released   In music she found her dream, her love, herself.
# 4     Released  His search for peace of mind... will leave his...
# ...        ...                                                ...
# 1276  Released                                                NaN
# 1277  Released                                                NaN
# 1278  Released  Evil came to the Southwest until three blazing...
# 1279  Released                                                NaN
# 1280  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                 Kate & Leopold    0.0           6.3
# 2                               The Silent Force    0.0           5.0
# 3                                        Glitter    0.0           4.6
# 4                          The Attic Expeditions    0.0           5.1
# ...                                          ...    ...           ...
# 1276  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 1277         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 1278                        Guns Along The Bravo    0.0           0.0
# 1279                                   New Breed    0.0           0.0
# 1280                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 0           NaN           NaN
# 1        1117.0         PG-13
# 2           3.0           NaN
# 3         115.0         PG-13
# 4          28.0             R
# ...         ...           ...
# 1276        0.0           NaN
# 1277        0.0           NaN
# 1278        0.0           NaN
# 1279        0.0            NR
# 1280        2.0           NaN
#
# [1281 rows x 26 columns]

# %%
tmdb = pd.concat([tmdb_2000, tmdb_2001], axis=0)
tmdb
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1276  tt7797670    0.0                               NaN
# 1277  tt7797790    0.0                               NaN
# 1278  tt8665056    0.0                               NaN
# 1279  tt8795764    0.0                               NaN
# 1280  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...                    ...         ...
# 1276                   NaN         0.0
# 1277                   NaN         0.0
# 1278                   NaN         0.0
# 1279                   NaN         0.0
# 1280                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1276                     [{'id': 27, 'name': 'Horror'}]
# 1277                     [{'id': 27, 'name': 'Horror'}]
# 1278                    [{'id': 37, 'name': 'Western'}]
# 1279                     [{'id': 27, 'name': 'Horror'}]
# 1280                     [{'id': 28, 'name': 'Action'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   62127.0
# 2                                                   NaN  110977.0
# 3                                                   NaN  442869.0
# 4                  http://www.wkw-inthemoodforlove.com/     843.0
# ...                                                 ...       ...
# 1276                                                NaN  956214.0
# 1277                                                NaN  956219.0
# 1278  http://skeletoncreekproductions.com/p-movie-br...  885436.0
# 1279  https://www.utahwolf.com/films/coming-soon-new...  871624.0
# 1280    http://www.hkcinemagic.com/en/movie.asp?id=6627  201706.0
#
#      original_language                              original_title  ...  \
# 0                  NaN                                         NaN  ...
# 1                   en                             The Fantasticks  ...
# 2                   en                               For the Cause  ...
# 3                   hi                                        Gang  ...
# 4                   cn                                        花樣年華  ...
# ...                ...                                         ...  ...
# 1276                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 1277                en         Edmund Kemper Part 3: La mort sévit  ...
# 1278                en                        Guns Along The Bravo  ...
# 1279                en                                   New Breed  ...
# 1280                cn                                        致命密函  ...
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0    152.0  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...
# 4     12854953.0     99.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
# ...          ...      ...                                                ...
# 1276         0.0     91.0                                                 []
# 1277         0.0     72.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1278         0.0     85.0                                                 []
# 1279         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1280         0.0     90.0  [{'english_name': 'Cantonese', 'iso_639_1': 'c...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released      Try to remember the first time magic happened
# 2     Released       The ultimate showdown on a forbidden planet.
# 3     Released                                                NaN
# 4     Released  Feel the heat, keep the feeling burning, let t...
# ...        ...                                                ...
# 1276  Released                                                NaN
# 1277  Released                                                NaN
# 1278  Released  Evil came to the Southwest until three blazing...
# 1279  Released                                                NaN
# 1280  Released                                                NaN
#
#                                            title  video  vote_average  \
# 0                                            NaN    NaN           NaN
# 1                                The Fantasticks    0.0           5.4
# 2                                  For the Cause    0.0           4.4
# 3                                           Gang    0.0           0.0
# 4                           In the Mood for Love    0.0           8.1
# ...                                          ...    ...           ...
# 1276  Edmund Kemper Part 2: La Mort C'est La Vie    0.0           0.0
# 1277         Edmund Kemper Part 3: La mort sévit    0.0           0.0
# 1278                        Guns Along The Bravo    0.0           0.0
# 1279                                   New Breed    0.0           0.0
# 1280                              Chinese Heroes    0.0           3.0
#
#      vote_count certification
# 0           NaN           NaN
# 1          21.0           NaN
# 2           7.0           NaN
# 3           0.0           NaN
# 4        1882.0            PG
# ...         ...           ...
# 1276        0.0           NaN
# 1277        0.0           NaN
# 1278        0.0           NaN
# 1279        0.0            NR
# 1280        2.0           NaN
#
# [2479 rows x 26 columns]

# %%
tmdb_data = tmdb[["imdb_id","revenue","budget","certification"]]
tmdb_data.head()
# Out:
#      imdb_id     revenue      budget certification
# 0          0         NaN         NaN           NaN
# 1  tt0113026         0.0  10000000.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694  12854953.0    150000.0            PG

# %%
tmdb_data.rename(columns={"imdb_id":"tconst"}, inplace=True)
# Out:
# C:\Users\Bijan Emadi\anaconda\envs\dojo-env\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
tmdb_data.dtypes
# Out:
# tconst            object
# revenue          float64
# budget           float64
# certification     object
# dtype: object

# %%
imdb_id_len = tmdb_data["tconst"].fillna('').map(len).max()
cert_len = tmdb_data["certification"].fillna('').map(len).max()
df_schema = {
    "tconst": String(imdb_id_len+1),
    "budget": Float(),
    "revenue": Float(),
    "certification":Text(cert_len+1)
}

# %%
tmdb_data.to_sql("tmdb_data",engine,dtype=df_schema,if_exists='replace',index=False)

# %%
q = """SHOW TABLES;"""
pd.read_sql(q,engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4        tmdb_data

# %%
q = """SELECT *
FROM genres
LIMIT 3;"""
pd.read_sql(q,engine)
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2

# %%
q = """SELECT *
FROM title_basics
LIMIT 3;"""
pd.read_sql(q,engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
#
#   endYear  runtimeMinutes
# 0    None             118
# 1    None              70
# 2    None             122

# %%
q = """SELECT *
FROM title_genres
LIMIT 3;"""
pd.read_sql(q,engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18

# %%
q = """SELECT *
FROM title_genres
LIMIT 3;"""
pd.read_sql(q,engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18

# %%
q = """SELECT *
FROM tmdb_data
LIMIT 3"""
pd.read_sql(q,engine)
# Out:
#       tconst  revenue      budget certification
# 0          0      NaN         NaN          None
# 1  tt0113026      0.0  10000000.0          None
# 2  tt0113092      0.0         0.0          None
